# %% [markdown]
# # Studio distribuzione variabili qualitative

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/loren/Desktop/Python/Pandas/googleplaystore/task 1 googleplaystore pulito.csv')

# %%
df['Last Updated'] = pd.to_datetime(df['Last Updated'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9659 entries, 0 to 9658
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          9659 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            9659 non-null   float64
#  5   Installs        9659 non-null   float64
#  6   Type            9658 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   datetime64[ns]
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     9657 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(7)
# memory usage: 981.1+ KB

# %% [markdown]
# ### Categorie qualitative:
# 1. Category
# 2. Type
# 3. Content Rating
# 4. Genres
#
# L'analisi della distribuzione dei dati all'interno di queste variabili avverrà attraverso la visualizzazione della frequenza assoluta & relativa in formato grafico e tabellare.

# %%
df[['Category', 'Type', 'Content Rating', 'Genres']].describe()
# Out:
#        Category  Type Content Rating Genres
# count      9659  9658           9659   9659
# unique       33     2              6    118
# top      FAMILY  Free       Everyone  Tools
# freq       1878  8904           7903    828

# %% [markdown]
# La variabile 'Genres' presenta un numero di valori molto alto qundi rappresentero graficamente solo i primi 30

# %%
def grafico_frequenza_assoluta(df, serie):
    plt.figure(figsize=(10,12))
    sns.countplot(data= df, y=serie, palette= 'magma', order= df[serie].value_counts().index)
    plt.title(f'Distribuzione(%) {serie}')
    plt.xlabel('Frequenza Assoluta')
    plt.ylabel('')

# %%
def grafico_frequenza_relativa(df, serie):
    relativa = (df[serie].value_counts() / len(serie) * 100).round(2)
    
    plt.figure(figsize=(10,12))
    sns.countplot(data= df, y=serie, palette= 'magma', order=relativa.index)
    plt.title(f'Distribuzione(%) {serie}')
    plt.xlabel('Frequenza Relativa(%)')
    plt.ylabel('')

# %%
def tabella_frequenze(df, serie):
    return pd.concat([df[serie].value_counts(), round(df[serie].value_counts() / len(df) * 100, 2)], axis= 1, keys= ['Assoluta' , 'Relativa(%)']).reset_index().rename(columns={'index': serie})

# %%
grafico_frequenza_assoluta(df, 'Category')

# %%
grafico_frequenza_relativa(df, 'Category')

# %%
tabella_frequenze(df, 'Category')
# Out:
#                Category  Assoluta  Relativa(%)
# 0                FAMILY      1878        19.44
# 1                  GAME       945         9.78
# 2                 TOOLS       829         8.58
# 3              BUSINESS       420         4.35
# 4               MEDICAL       395         4.09
# 5       PERSONALIZATION       376         3.89
# 6          PRODUCTIVITY       374         3.87
# 7             LIFESTYLE       369         3.82
# 8               FINANCE       345         3.57
# 9                SPORTS       325         3.36
# 10        COMMUNICATION       315         3.26
# 11   HEALTH_AND_FITNESS       288         2.98
# 12          PHOTOGRAPHY       281         2.91
# 13   NEWS_AND_MAGAZINES       254         2.63
# 14               SOCIAL       239         2.47
# 15  BOOKS_AND_REFERENCE       222         2.30
# 16     TRAVEL_AND_LOCAL       219         2.27
# 17             SHOPPING       202         2.09
# 18               DATING       170         1.76
# ...

# %%
grafico_frequenza_assoluta(df, 'Type')

# %%
grafico_frequenza_relativa(df, 'Type')

# %%
tabella_frequenze(df, 'Type')
# Out:
#    Type  Assoluta  Relativa(%)
# 0  Free      8904        92.18
# 1  Paid       754         7.81

# %%
grafico_frequenza_assoluta(df, 'Content Rating')

# %%
grafico_frequenza_relativa(df, 'Content Rating')

# %%
tabella_frequenze(df, 'Content Rating')
# Out:
#     Content Rating  Assoluta  Relativa(%)
# 0         Everyone      7903        81.82
# 1             Teen      1036        10.73
# 2       Mature 17+       393         4.07
# 3     Everyone 10+       322         3.33
# 4  Adults only 18+         3         0.03
# 5          Unrated         2         0.02

# %%
tabella_frequenze(df, 'Genres')
# Out:
#                                  Genres  Assoluta  Relativa(%)
# 0                                 Tools       828         8.57
# 1                         Entertainment       561         5.81
# 2                             Education       510         5.28
# 3                              Business       420         4.35
# 4                               Medical       395         4.09
# ..                                  ...       ...          ...
# 113                     Tools;Education         1         0.01
# 114                 Adventure;Education         1         0.01
# 115  Video Players & Editors;Creativity         1         0.01
# 116                 Strategy;Creativity         1         0.01
# 117              Role Playing;Education         1         0.01
#
# [118 rows x 3 columns]

# %%
df_top_30_genres = pd.concat([df['Genres'].value_counts().head(30), (df['Genres'].value_counts().head(30) / 30 * 100).round(2)], axis= 1, keys= ['Assoluta', 'Relativa']).reset_index().rename(columns= {'index': 'Genres'})

# %%
df_top_30_genres
# Out:
#                      Genres  Assoluta  Relativa
# 0                     Tools       828   2760.00
# 1             Entertainment       561   1870.00
# 2                 Education       510   1700.00
# 3                  Business       420   1400.00
# 4                   Medical       395   1316.67
# 5           Personalization       376   1253.33
# 6              Productivity       374   1246.67
# 7                 Lifestyle       368   1226.67
# 8                   Finance       345   1150.00
# 9                    Sports       331   1103.33
# 10            Communication       315   1050.00
# 11                   Action       299    996.67
# 12         Health & Fitness       288    960.00
# 13              Photography       281    936.67
# 14         News & Magazines       254    846.67
# 15                   Social       239    796.67
# 16        Books & Reference       222    740.00
# 17           Travel & Local       218    726.67
# 18                 Shopping       202    673.33
# ...

# %%
plt.figure(figsize=(10,12))
sns.barplot(data= df_top_30_genres, x= 'Assoluta', y= 'Genres', palette= 'magma')
plt.title('Distribuzione Top 30 genres')
plt.xlabel('')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
plt.figure(figsize=(10,12))
sns.barplot(data= df_top_30_genres, x= 'Relativa', y= 'Genres', palette= 'magma')
plt.title('Distribuzione Top 30 genres')
plt.xlabel('Frequenza Relativa(%)')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')
